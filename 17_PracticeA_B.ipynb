# %% [markdown]
# Krrish Kishore Kumar

# %% [markdown]
# # 17A: Exploring Global Wildlife changes using NumPy
#
# Using NumPy and Matplotlib

# %% [markdown]
# ## Goals:
#
# By the end of this assignment you should be able to:
# - Load data using NumPy and visualize it using matplotlib
# - Compute simple statistics of NumPy "array" objects
# - Use NumPy and matplotlib to identify correlation, if it exists

# %% [markdown]
# ## Using NumPy to explore the changes in global wildlife

# %% [markdown]
# To use this notebook for your in-class assignment, you will need these files:
# * `Asia Pacific Index.csv`
# * `Fresh Water living index.csv`
# * `North America living index.csv`
#
#
# These files are provided in Schoology along with the assignment. You will need to read data from these files. To simplify the process, make sure you download the files to the same place as the Jupyter notebook on your computer.
#
# _Take a moment to look at the contents of these files with an editor on your computer._  For example, `*.csv` files open with Excel or just try opening it inside your Jupyter Notebook interface.

# %% [raw]
# In order to actually use the files, we need to load the data into Python. This is done via NumPy, so you first need to import that module.
# Also import matplotlib.pyplot at the same time, as you will be using it to plot the data once it is loaded.

# %% [markdown]
# Although there are some exceptions, it is generally a good idea to keep all of your imports in one place
# so that you can easily manage them. Doing so also makes it easy to copy all of them at once and paste them
# into a new notebook you are starting.
#
# - import numpy as np
# - import matplotlib.pyplot as plt
# - %matplotlib inline (for inline printing of graphs)

# %%
# Import NumPy and Matplotlib, and include the line "%matplotlib inline", allowing for plots inside of the notebook.

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now that the modules are loaded, we can begin to read the files into Python.
# The files should be loaded using the following names:
#
# - name_date and nam_data
# - fresh_date and fresh_data
# - asia_date and asia_data
#
# Remember, you can use the following command example to load the data.
# - nam_date, nam_data = np.loadtxt("North America living index.csv", usecols=(0,1),unpack=True,skiprows=1,delimiter=',')
#
# **Don't just copy and paste, actually type in the commands to load the data, and think about what each part of the command is telling the Python to do**

# %%
# Load the CSV files and unpack
# NA data

nam_date, nam_data = np.loadtxt("North_America_living_index.csv", usecols=(0,1),unpack=True,skiprows=1,delimiter=',')
# freshwater data
fresh_date, fresh_data = np.loadtxt("Fresh_Water_living_index.csv", usecols=(0,1),unpack=True,skiprows=1,delimiter=',')
# asia pacific data
asia_date, asia_data = np.loadtxt("Asia_Pacific_Index.csv", usecols=(0,1),unpack=True,skiprows=1,delimiter=',')

# %% [markdown]
# Print the three data files to make sure that it imported correctly. Then comment it out.

# %%
# print it just to take a look at it and make sure it imported correctly. Remember to comment # it out afterwards.

# print(nam_date, nam_data)
# print(fresh_date, fresh_data)
# print(asia_date, asia_data)

# %% [markdown]
# We also need to verify that each of the files loaded as an array. Confirm the data type of each in the cell below.

# %%
# verify that it imported as a NumPy array using the 'type' query

print(type(nam_data))
print(type(fresh_data))
print(type(asia_data))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %% [markdown]
# With data imported into Python, we can begin to use NumPy's statistal ability to
# determine some basic informations such as the mean, median, and standard deviation. To determine how to do this, check out the NumPy documentation here:
# [statistics operations](https://docs.scipy.org/doc/numpy-1.13.0/reference/routines.statistics.html)

# %%
# Type your code here

np.mean(nam_data)
np.median(nam_data)
np.std(nam_data)
# Out:
# 8.723721241582355

# %% [markdown]
# Let's see if a graph of the data puts these values in better perspective.
# To do that we will plot the date versus the data using matplotlib. Do this for the three files so they are all on one graph.
# This is how data science begins to come alive; using real data and making sense of the values.
# While it is a simple, first step. Understanding how data can be presented and represented (or misrepresented) are important concepts.

# %%
# Type your code here

plt.plot(nam_date, nam_data, label='North America')
plt.plot(fresh_date, fresh_data, label='Fresh Water')
plt.plot(asia_date, asia_data, label='Asia Pacific')

plt.title('Global Wildlife Changes Over Time')
plt.xlabel('Year')
plt.ylabel('Index Value')
plt.legend()
plt.show()

# %% [markdown]
# _Make sure your graph above has a title, labels and legend._

# %% [markdown]
# ### 17B: Representations with subplots
# This time, make each location on its own graph in a single diagram. Remember that you are working with three datasets. Ensure you include:
# - 𝑥 axis labels
# - 𝑦 axis labels
# - grid lines using plt.grid()
# - markers versus a single line
# - a title.

# %%
plt.subplot(3,1,1)
plt.plot(nam_date, nam_data, label='North America')
plt.title('North America')
plt.xlabel('Year')
plt.ylabel('Index Value')
plt.legend()
plt.show()

plt.subplot(3,1,2)
plt.plot(fresh_date, fresh_data, label='Fresh Water')
plt.title('Fresh Water')
plt.xlabel('Year')
plt.ylabel('Index Value')
plt.legend()
plt.show()

plt.subplot(3,1,3)
plt.plot(asia_date, asia_data, label='Asia Pacific')
plt.title('Asia Pacific')
plt.xlabel('Year')
plt.ylabel('Index Value')
plt.legend()
plt.show()

# %% [markdown]
# Once you have made three separate graphs with the items above, make all of them in the same plot using the same formating techniques you used in the separate plots but also add a legend.
#
# Remember, getting help is normal. Ask a partner, the teacher, or searching the internet for ideas and example code.

# %%
# Type your code here

plt.plot(nam_date, nam_data, label='North America')
plt.plot(fresh_date, fresh_data, label='Fresh Water')
plt.plot(asia_date, asia_data, label='Asia Pacific')

plt.title('Global Wildlife Changes Over Time')
plt.xlabel('Year')
plt.ylabel('Index Value')
plt.legend()
plt.show()

# %% [markdown]
# &#9999;&nbsp; **What observations about the data do you have?** **Do you see any overall trends? Put your answer here**:

# %% [markdown]
# 1. **North America**: The index value shows a general decline over the years, indicating a decrease in wildlife populations.
# 2. **Fresh Water**: Similar to North America, the Fresh Water index also shows a declining trend, though there are some fluctuations.
# 3. **Asia Pacific**: The Asia Pacific index shows a more pronounced decline compared to the other two regions.
#
# Overall, all three regions show a declining trend in wildlife populations over the years. This suggests that global wildlife populations are decreasing, which could be due to various factors such as habitat loss, climate change, pollution, and over-exploitation of resources.
#
# To further analyze the data, we can look at the year-over-year changes in the index values to identify specific periods of significant decline. This will help us understand if there are any particular events or factors that contributed to these changes.
# ```

# %% [markdown]
# #### One of the problems with raw data is that it often is not presented in the form that we need.
# Now that we see the overall trends, what we really need to identify is if there are differences in how the three measures decrease. In other words, are there specific causes that can account the various drops?
# To do this, we need to see where the changes in the wilds are the most significant.
#
# Instead of looking at the percentage based on the 1970's 100%, we will examine how much the measure changed each year. This works differently with arrays than with lists.

# %%
import matplotlib.pyplot as plt
# Let's try the typical method that is used with lists to find the difference.
#nam_change = []
#for i in nam_data:
 #   name_change = nam.data(i) - name.data(i+1)
# Type code in together here.
nam_change = np.diff(nam_data) # calculates difference from i to i+1
fresh_change = np.diff(fresh_data)
asia_change = np.diff(asia_data)

nam_date_change = np.delete(nam_date,0)
fresh_date_change = np.delete(fresh_date,0)
asia_date_change = np.delete(asia_date,0)


plt.plot(nam_date_change,nam_change, label = "North America",marker=".")
plt.plot(fresh_date_change,fresh_change, label = "Freshwater",marker=".")
plt.plot(asia_date_change,asia_change, label = "Asia",marker=".")
plt.legend()
plt.xlabel("Years")
plt.ylabel("Change in Living Planet Index per Year")
plt.title("Change in Living Planet Index in Locations Over Time")
plt.show()

# %% [markdown]
# What does the graph above tell you? What do you think some of the next steps might be for analysis of this information?
#
# &#9999; The graph above shows the year-over-year changes in the Living Planet Index for the three locations. It provides insights into the rate of change in wildlife populations over time, highlighting periods of significant decline or improvement.

# %% [markdown]
# ### Looking for correlations in data.
#
# In the plots above, you looked at the Living Planet measurements across time in three different locations on Earth. This makes sense as that is how the data was provided. But, what if we want to better understand how the changes in the Living Planet correlate in different parts of the world. It could help us to better understand the interconnectedness of the environment or the impact of global warming or population growth.
#
# Truly understanding the data in these more abstract ways is where data science continues to make inroads in our understanding. Did certain larger dips correlate with large-scale weather patterns or something else? By looking at correlations and patterns, we can begin to better understand the trends in the data.
#
# In order to see this, we need to plot the Living Planet values of one location versus another location. Note that we will not include the dates in this graph. However, that does not minimize the value.
#
# ----
#
# In the cells below, create plots of one area's Living Planet Index against another area, have each graph represented by 'x' at the points and no line.
# Do this so that in the end each area is compared to the other two.
# Make sure each plot is shown separately.
# (You can use [subplot] or another method that you are comfortable with. This is a link to various example in matplotlib using subplots. (https://matplotlib.org/examples/pylab_examples/subplots_demo.html))

# %%
# Type your code here
plt.subplot(3,1,1)
plt.plot(nam_data,fresh_data, "x")
plt.xlabel("North American Living Planet Index")
plt.ylabel("Freshwater Living Planet Index")
plt.title("North American Living Planet Index Vs. Freshwater Living Planet Index")
plt.show()


plt.subplot(3,1,2)
plt.plot(nam_data,asia_data, "x")
plt.xlabel("North American Living Planet Index")
plt.ylabel("Asia Living Planet Index")
plt.title("North American Living Planet Index Vs. Asia Living Planet Index")
plt.show()


plt.subplot(3,1,3)
plt.plot(asia_data,fresh_data,"x")
plt.xlabel("Asia Living Planet Index")
plt.ylabel("Freshwater Living Planet Index")
plt.title("Asia Living Planet Index Vs. Freshwater Living Planet Index")
plt.show()

# %% [markdown]
# ### Making connections
# - What do you notice using the graphs above?
# - Is there anything specifically that stands out?
# - Do you have any hypothesis on why certain fluctuations in the data occurred at specific times?
# Write your answers in the cell below.

# %% [markdown]
# &#9999; I notice that there are some correlations between the Living Planet Index values of different locations. For example, there seems to be a positive correlation between the North American and Freshwater Living Planet Index values, as well as between the North American and Asia Living Planet Index values. This suggests that changes in wildlife populations in one location may be related to changes in another location.

# %% [markdown]
# ### Saving Plots
#
# When you are presenting your findings, you aren't going to include all of your code. It is important to be able to save your graphs for future use and/or publication.
# You can save figures in different formats, depending on your purposes.
#
# Here are two examples of how you could save you work as a picture or pdf.
#
# `plt.savefig('WildEarth.png')`
# `plt.savefig('WildEarth.pdf')`
#
# Go back to your code above and save the figures you created.
